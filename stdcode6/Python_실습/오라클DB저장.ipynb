# %%
# 1. 급여가 800만원 이상인 사원의 사원명, 직급코드를 출력하시오
# 2. 입사일이 2010년~2018년 사이인 사원의 사원명, 부서코드, 급여, 입사일을 출력하시오
# 3. 입사일이 2020년 08월이면서 부서코드가 'C'가 아닌 사원의 사원명, 근무지코드, 부서코드를 출력하시오
# 4. 사원의 총인원수를 출력하시오
# 5. 상급자사원번호가 없는 사원의 총인원수와 총급여합을  출력하시오
# 6. 급여가 300만원이하이면서 2020년 08월 15일 이후에 입사한 사원의 총인원수와 총급여합을 출력하시오
# 7. '한' 씨 성을 가진 사원들을 출력하시오
# 8. 직급별 급여의 평균을 출력하시오(반올림해서 정수만 출력)
# 9. 사원명에 '삭' 자가 포함되어 있거나 '김'씨 성을 가진 사원의 급여합을 출력하시오
# 10. 부서별 사원수를 출력하시오
# 11. 근무지별 사원의 총인원수를 출력하시오
# 12. 가장 높은 급여와 가장 낮은 급여를 출력하시오
# 13. 급여가 500만원 이상, 800만원 이하인 사원의 급여평균과 급여의 최대값을 출력하시오
# 14. 가장 높은 급여와 가장 낮은 급여의 차를 출력하시오
# 15. 근무지가 'A1'이 아닌 사원들의 부서코드별 사원수를 출력하시오
# 16. 부서코드별 사원번호순으로 부서코드, 사원번호, 사원명, 급여의 누적값을 구해서 출력하시오
# 17. 부서명, 사원명 출력하시오 
# 18. 전체 사원명과 부서명을 출력하되 부서명이 존재하지 않는 부서코드는 '부서명없음'으로 출력하시오
# 19. 부서명으로 오름차순 정렬해서 부서명, 사원명, 입사일을 출력하시오
# 20. 부서명과 부서별 사원의 총인원수를 출력하시오
# 21. 사원명을 출력하되 급여가 100만원 미만이면 0, 100만원~200만원 사이면 200, 200만원~300만원이면 300...(구간대를 1000만원까지) 을 함께 출력하시오(사원별 급여구간)
# 22. 사원이 속한 모든 부서의 부서별 부서명과 급여합을 출력하시오
# 23. 부서별 부서명, 최소급여, 최대급여 출력하시오
# 24. 전체 사원을 대상으로 사원번호, 사원명, 상급자사원번호, 상급자사원명을 출력하시오(상급자사원번호가 없는 사원이 상급자임)
# 25. 상급자사원명이 '허잔석' 인 사원들의 부서명별 급여평균을 출력하시오
# 26. 부서별 급여의 합이 1억원이 넘는 부서의 부서명과 해당 부서의 급여합을 출력하시오
# 27. 전체 사원을 대상으로 부서별 사원수가 2명 미만인 부서의 부서코드, 부서명, 사원수를 출력하시오(부서명이 없으면 '부서명없음'으로 출력)
# 28. 부서별로 부서코드, 부서명, 사원수를 출력하되 부서명이 존재 하지 않으면 부서명은 '부서명없음', 사원수를 0으로 출력하시오
# 29. 가장 많은 사원을 데리고 있는 상급자의 상급자명, 부서명을 출력하시오
# 30. 부서명이 등록되지 않은 사원과 직급이 같고 현황조사를 하고 있는 사원의 사원명, 직급명을 출력하시오
# 31. 직급별로 최소 급여를 받고 있는 사원의 사원번호, 사원명, 부서명, 급여를 급여의 내림차순 정렬로 출력하시오
# 32. 각 사원의 시급을 계산(근무일수 20일, 9시간근무, 소수 첫번째 자리에서 반올림)해서 부서명, 사원명, 직급명, 시급을 부서명별, 시급이 많은 순으로 출력하시오
# 33. 직급별 입사일이 가장 오래된 사원에 대해 사원명, 직급명, 입사년도를 출력하시오

# %% [markdown]
# # 참조. 데이터베이스 데이터 수집 및 저장 (Oracle)

# %%
# 설치필요 라이브러리 : pip install cx_Oracle
import pandas as pd
from sqlalchemy import create_engine,types
id = "kopo"
pw = "kopo"
ip = "192.168.110.112"
port = "1521"
dbName = "orcl"
# DB 커넥션 열기
engine = create_engine('oracle+cx_oracle://{}:{}@{}:{}/{}'.format(id,pw,ip,port,dbName)    )

# %%
# 테이블 전체 조회 select * from tabs와 유사
engine.table_names()
# Out:
# C:\Users\SMART07\AppData\Local\Temp\ipykernel_14112\3660316655.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['oracleresult_BaeUk1',
#  'kopo_decision_tree',
#  'kopo_test_result',
#  'test',
#  'test2',
#  'kopo_channel_seasonality_hk',
#  'kopo_batch_season_mpara2',
#  'kopo_st_hk',
#  'kopo_st_kj',
#  'kopo_st_hyo',
#  'kopo_st_kh',
#  'kopo_st_mh',
#  'kopo_st_shb',
#  'kopo_st_ty',
#  'kopo_st_hj',
#  'kopo_st_h1',
#  'kopo_st_ysh',
#  'kopo_st_psj',
#  'kopo_st_kgy',
#  'kopo_st_lhm',
#  'kopo_st_kjs',
#  'kopo_st_kdw',
#  'kopo_st_dwk',
#  'kopo_st_lws',
#  'kopo_st_se',
#  'kopo_st_mj',
#  'kopo_st_es',
#  'kopo_st_dave',
#  'kopo_st_ys',
#  'kopo_st_dg',
#  'kopo_st_ms',
#  'kopo_st_cho',
#  'kopo_st_jy',
#  'kopo_st_ejkim',
#  'kopo_st_sw',
#  'kopo_product_master',
#  'kopo_channel_seasonality_ex',
#  'kopo_channel_seasonality_ssw2',
#  'kopo_region_mst',
#  'toad_plan_sql',
#  'kopo_channel_result_new',
#  'student_info',
#  'lesson_inf',
#  'test_leftjoindata',
#  'test111',
#  'mst1',
#  'season1',
#  'lefttable',
#  'righttable',
#  'lefttable1',
#  'reighttable',
#  'righttable1',
#  'righttauble',
#  'lefttable_pf',
#  'righttable_pf',
#  'promotion_pf',
#  'promotable',
#  'promotiontable',
#  'copytable',
#  'KOPO_PRODUCT_VOLUME_ST_김지성',
#  'kopo_product_volume_st_ejkim',
#  'KOPO_PRODUCT_VOLUME_ST_신성우',
#  'rmse_mae_example_step2',
#  'RMSE_MAE_EXAMPLE_STEP2_김효관_1',
#  'storeData_lws',
#  'kopo_product_hty',
#  'part_col_privs',
#  'cds',
#  'columns_v2',
#  'partition_key_vals',
#  'dbs',
#  'partition_params',
#  'KOPO_STOCK_ST_조정연',
#  'rmse_mae_example',
#  'serdes',
#  'sort_example',
#  'types',
#  'partition_keys',
#  'roles',
#  'partitions',
#  'index_params',
#  'tbl_col_privs',
#  'idxs',
#  'kopo_predict_middleresult2',
#  'bucketing_cols',
#  'type_fields',
#  'sd_params',
#  'global_privs',
#  'sds',
#  'table_params',
#  'sort_cols',
#  'tbl_privs',
#  'database_params',
#  'role_map',
#  'serde_params',
#  'part_privs',
#  'db_privs',
#  'RMSE_MAE_EXAMPLE_STEP2_이우석_2',
#  'RMSE_MAE_EXAMPLE_STEP2_박승진_1',
#  'RMSE_MAE_EXAMPLE_STEP2_박승진_2',
#  'RMSE_MAE_EXAMPLE_STEP2_정경화_1',
#  'users',
#  'kopo_promotion_new',
#  'RMSE_MAE_EXAMPLE_STEP2_이한민_2',
#  'RMSE_MAE_EXAMPLE_STEP2_이한민_1',
#  'rmse_mae_example_step2_shb_1',
#  'rmse_mae_example_step2_shb_2',
#  'rmse_mae_example_step3',
#  'RMSE_MAE_EXAMPLE_STEP2_이동근_1',
#  'RMSE_MAE_EXAMPLE_STEP2_이동근_2',
#  'RMSE_MAE_EXAMPLE_STEP2_정경화_2',
#  'RMSE_MAE_EXAMPLE_STEP2_윤성호_1',
#  'RMSE_MAE_EXAMPLE_STEP2_이우석_1_1',
#  'RMSE_MAE_EXAMPLE_STEP2_윤성호_2',
#  'RMSE_MAE_EXAMPLE_STEP2_이우석_1',
#  'RMSE_MAE_EXAMPLE_STEP2_김효관_정유석',
#  'RMSE_MAE_EXAMPLE_STEP2_김강용_B',
#  'mse_mae_example_step2_hyojaejung_1',
#  'mse_mae_example_step2_hyojaejung_2',
#  'absdssdd',
#  'hk_222',
#  'abc',
#  'rmse_mae_example_step2_dave_1',
#  'rmse_mae_example_step2_dave_2',
#  'kopo_psj_order',
#  'kopo_parameter_ssw',
#  'kopo_psj_payment',
#  'x_policy_export_audit',
#  'KOPO_SPARK_ST_조동역',
#  'KOPO_SPARK_ST_이효재',
#  'x_resource',
#  'KOPO_SPARK_ST_오미진',
#  'x_trx_log',
#  'kopo_parameter_ssw1',
#  'oracleresult_jys',
#  'x_perm_map',
#  'x_audit_map',
#  'x_service_def',
#  'x_service',
#  'x_policy',
#  'kopo_spark_st_dave',
#  'x_service_config_def',
#  'x_resource_def',
#  'x_access_type_def',
#  'x_access_type_def_grants',
#  'x_policy_condition_def',
#  'x_context_enricher_def',
#  'kopo_product_volume_st_cse',
#  'kopo_product_volume_cse',
#  'kopo_product_volume_st_정경화',
#  'kopo_product_volume_st_jkh',
#  'kopo_product_volume_st_noh',
#  'kopo_product_st_noh',
#  'python_team_three',
#  'spark_team_three',
#  'RMSE_MAE_EXAMPLE_STEP2_채성은_1',
#  'RMSE_MAE_EXAMPLE_STEP2_김의진2',
#  'RMSE_MAE_EXAMPLE_STEP2_김의진1',
#  'RMSE_MAE_EXAMPLE_STEP2_오미진_1',
#  'RMSE_MAE_EXAMPLE_STEP2_오미진_2',
#  'RMSE_MAE_EXAMPLE_STEP2_김강용_1',
#  'RMSE_MAE_EXAMPLE_STEP2_김강용_A',
#  'RMSE_MAE_EXAMPLE_STEP2_채성은_2',
#  'RMSE_MAE_EXAMPLE_STEP2_신성우_1_1',
#  'RMSE_MAE_EXAMPLE_STEP2_신성우_1_2',
#  'RMSE_MAE_EXAMPLE_STEP2_최경재_1',
#  'rmse_mae_example_step2_lhj_1',
#  'RMSE_MAE_EXAMPLE_STEP2_최경재_2',
#  'RMSE_MAE_EXAMPLE_STAP2_김효관_1',
#  'RMSE_MAE_EXAMPLE_STAP2_김효관_2',
#  'RMSE_MAE_EXAMPLE_STEP2_김강용_2',
#  'testkkk',
#  'KOPO_PRODUCT_VOLUME_ST_JHJ_fix',
#  'oracleresult_JHJ',
#  'kopo_product_volume_st_shb',
#  'kopo_product_volume_st_ldg',
#  'KOPO_PRODUCT_VOLUME_ST_윤성호',
#  'oracleresult_PSJ',
#  'oracleResult_kgy',
#  'kopo_st_product',
#  'kopo_event_info_foreign',
#  'oracleresult_lhj',
#  'kopo_product_volume_foreign',
#  'kopo_product_volue2',
#  'kopo_product_voluu2',
#  'refineddata',
#  'KOPO_DBatPY_이한민_FINAL1',
#  'KOPO_DBatPY_이한민_FINAL2',
#  'KOPO_DBatPY_이한민_FINAL3',
#  'KOPO_DBatPY_이한민_FINAL4',
#  'KOPO_DBatPY_이한민_FINAL5',
#  'KOPO_PY_채성은_FINAL1',
#  'KOPO_PY_박승진_FINAL1',
#  'kopo_st_result_hty',
#  'KOPO_PY_신성우_FINAL1',
#  'KOPO_CHANNEL_SEASONALITY_NEW_PIVOT박승진_1',
#  'KOPOPY{윤성호}_FINAL1',
#  'kopo_product_volume_st_jhj',
#  'KOPO_PRODUCT_VOLUME_ST_이한민',
#  'kopo_product_volume_st_psj',
#  'kopo_product_volume_st_kgy',
#  'kopo_product_volume_st_lhj',
#  'kopo_product_volume_kgy',
#  'kopo_channel_result',
#  'kopo_batch_season_result2',
#  'kopo_channel_seasnoality2',
#  'iris',
#  'kopo_sales_mst',
#  'kopo_channel_result_data',
#  'outresult1',
#  'kopo_channel_seasonality2',
#  'test_character',
#  'kopo_product_volue',
#  'kopo_product_volue_foreign',
#  'kopo_product_volume_foreign2',
#  'kopo_event_info_foreign2',
#  'kopo_event_info_test',
#  'kopo_channel_seasonality_new',
#  'kopo_new_logic_result',
#  'test1',
#  'leftjoinhyo',
#  'hk_join',
#  'kopo_product_volume_a01',
#  'kopo_product_volume_a02_new2',
#  'kopo_product_volume_a02_new',
#  'kopo_product_volume_a02',
#  'kopo_batch_season_mpara',
#  'kopo_channel_result_pivot',
#  'kopo_channel_result_pivot2',
#  'kopo_channel_seasonality_1',
#  'test_table',
#  'kopo_channel_result2',
#  'kopo_st_les_join1',
#  'kopo_st_hty3_join',
#  'kopo_st_jjy_join',
#  'kopo_st_m_join',
#  'kopo_st_jyj_join',
#  'kopo_st_jjy2_join',
#  'kopo_st_dave1_join',
#  'kopo_st_kjs_join',
#  'kopo_st_lws_join',
#  'kopo_st_cmh_join',
#  'asdasd',
#  'kopo_st_ldg_join',
#  'testhk',
#  'testjs',
#  'seasonmstjoin',
#  'testjhj',
#  'hyojointest',
#  'toad_plan_table',
#  'kopo_channel_result_a01',
#  'kopo_channel_result_a02',
#  'kopo_channel_result_a01_a02',
#  'kopo_customerdata',
#  'kopo_product_mst',
#  'kopo_channel_seasonality_new2',
#  'kopo_hk_season_mpara',
#  'kopo_parameter',
#  'kopo_stock_exp',
#  'kopo_stock_log',
#  'kopo_stock_mst',
#  'kopo_st_ssw_leftjoin',
#  'kopo_kgy_join',
#  'kopo_st_lhm_join',
#  'kopo_st_psj_join',
#  'kopo_st_hty_join',
#  'kopo_st_shb_join',
#  'kopo_kospi_join_ex_hyo',
#  'kopo_st_omj_join',
#  'kopo_st_lhj_join',
#  'kopo_st_ysh_join',
#  'kopo_st_ssw_join',
#  'kopo_st_cse_join',
#  'kopo_st_jkh_join',
#  'kopo_st_kej_join',
#  'kopo_st_nyw_join',
#  'kopo_st_pjs_join',
#  'kopo_st_ssw_join2',
#  'kopo_st_pjspsj_join',
#  'kopo_st_dave_join',
#  'kopo_st_jys_join',
#  'kopo_st_hty1_join',
#  'kopo_st_cho_join',
#  'kopo_st_ckj_join',
#  'kopo_channel_seasonality_mid',
#  'oracleresult_lhm',
#  'kopo_product_hty123',
#  'kopo_channel_seasonality_new_a01',
#  'rmse_mae_example2',
#  'rmse_mae_st_test2',
#  'rmse_mae_example_convert',
#  'oracleresult_ldg',
#  'kopo_product_hty1223',
#  'kopo_si_final_result',
#  'kopo_seasonality_smoothing_result',
#  'dt_result_final',
#  'kopo_decision_tree_example',
#  'psj_test1',
#  'test222',
#  'psj_test12',
#  'pivottest',
#  'KOPO_PY_김지성_FINAL2',
#  'KOPO_PY_김의진_FINAL2',
#  'hanbin_table_login',
#  'hanbin_table_first',
#  'kopo_product_list',
#  'kopo_product_volume_new2',
#  'kopo_product_volume_st',
#  'KOPO_PY_정답지_FINAL11',
#  'KOPO_PY_오미진_FINAL2',
#  'KOPO_PARAMETER_박승진10',
#  'KOPO_SPARK_ST_김효관22',
#  'kopo_product_volume_test',
#  'kopo_product_volume_test2',
#  'KOPO_PY_하태양_FINAL1',
#  'ldg_kgy',
#  't3_seasonality',
#  'kopo_product_volume_st_jh_jung',
#  'kopo_st_product1',
#  'kopo_st_order',
#  'rmse_mae_st_initail',
#  'rmse_mae_st_jhj',
#  'rmse_mae_st_omj',
#  'rmse_mae_st_hml',
#  'rmse_mae_st_les',
#  'rmse_mae_st_lws',
#  'rmse_mae_st_psj',
#  'rmse_mae_st_ssw',
#  'rmse_mae_st_khk',
#  'rmse_mae_st_cse',
#  'rmse_mae_st_lhj',
#  'rmse_mae_st_kgy',
#  'rmse_mae_st_ejkim',
#  'KOPO_PY_성한빈_FINAL3',
#  'rmse_mae_st_ckj',
#  'rmse_mae_st_jkh',
#  'KOPO_PY_조정연_FINAL2',
#  'oracleresult_hk',
#  'oracleresult_kjs',
#  'KOPO_PY_윤성호_FINAL1',
#  'KOPO_PY_김의진_FINAL3',
#  'kopo_parameter_hk',
#  'kopo_st_result',
#  'KOPO_PY_박승진_FINAL2',
#  'oracleresult_ssw',
#  'test1004',
#  'kopo_stock_st_ssw1',
#  'kopo_stock_st_1',
#  'KOPO_STOCK_ST_신성우',
#  'KOPO_STOCK_ST_신성우2',
#  'KOPO_STOCK_ST_신성우3',
#  'kopo_stock_st_ss',
#  'test_trim',
#  'kopo_2',
#  'KOPO_STOCK_ST_신성우1',
#  'kopo_st_ssw',
#  'KOPO_STOCK_ST_ssw',
#  'rmse_mae_st_jyj',
#  'rmse_mae_st_jjy',
#  'kopo_stock_st_sswww',
#  'kopo_stock_st_ssw',
#  'pro_fcst_result_final8',
#  'pro_fcst_result_final10',
#  'hansupythonconnect',
#  'kopo_predict_middleresult2_jar',
#  'pro_fcst_result_final9',
#  'plan_table',
#  'kopo_param_dohmisol',
#  'kopo_student_2018',
#  'kopo_bankdata_leeseungcheol',
#  'tbls',
#  'partition_events',
#  'skewed_string_list',
#  'skewed_string_list_values',
#  'skewed_col_names',
#  'RMSE_MAE_EXAMPLE_STEP2_조정연_2',
#  'smrt02_product',
#  'smrt02_user',
#  'RMSE_MAE_EXAMPLE_STEP2_조정연_1',
#  '상품',
#  'skewed_col_value_loc_map',
#  'gkxodid123',
#  'master_keys',
#  'delegation_tokens',
#  'skewed_values',
#  'tab_col_stats',
#  'version',
#  'pivottest_lws',
#  'part_col_stats',
#  'funcs',
#  'func_ru',
#  'notification_log',
#  'KOPO_DBatPY_이한민_FINAL6',
#  'KOPO_DB_IN_PY_이한민_FINAL1',
#  'KOPO_DB_IN_PY_이한민_FINAL2',
#  'KOPO_DB_IN_PY_이한민_FINAL3',
#  'KOPO_DB_IN_PY_이한민_FINAL4',
#  'KOPO_DB_IN_PY_이한민_FINAL5',
#  'KOPO_DB_IN_PY_이한민_FINAL6',
#  'KOPO_PY_이효재_FINAL1',
#  'kopo_group',
#  'KOPO_PY_이효재_FINAL2',
#  'KOPO_PY_{이우석}_FINAL1',
#  'oracleresult_cse',
#  'KOPO_PY_{이우석}_FINAL2',
#  'dt_result3',
#  'customer_name',
#  'elecresult2',
#  'KOPO_PY_박승진_FINAL3',
#  'KOPO_PY_정효재_FINAL3',
#  'KOPO_PY_이한민_FINAL3',
#  'oracleresult_JKH',
#  'test_hk',
#  'KOPO_PY_조동역_FINAL1',
#  'KOPO_PY_하태양_FINAL3',
#  'test_HK',
#  'oracleresult_jkh',
#  'test_HK2',
#  'oracleresult_jyj',
#  'oracleresult1',
#  'oracleresult_sung',
#  'oracleresult_psj',
#  'oracleresult_kgy',
#  'oracleresult_HTY',
#  'oracleresult_hty',
#  'oracleresult_ckj',
#  'KOPO_PY_정경화_FINAL1',
#  'oracleresult_les',
#  'oracleresult_hty123',
#  ' kop_py_정유석_FINAL2',
#  ' kopo_py_정유석_FINAL2',
#  ' KOPO_PY_정유석_FINAL2',
#  'clob2char',
#  'cl2ch2',
#  'cl2as',
#  'cstmrdata',
#  'KOPO_PY_윤성호_FINAL2',
#  'KOPO_PY_정유석_FINAL2',
#  'result_ejkim_clob2char',
#  'orc_jhj',
#  'KOPO_PY_오미진_FINAL3',
#  'KOPO_PY_Final_이한민',
#  'kopo_channel_seasonality_new_lower',
#  'kopo_channel_seasonality_linuxtest',
#  'kopo_predict_middleresult3_',
#  'final_python',
#  'kopo_seasonality_result_python',
#  'team4_seasonality_final_spark',
#  'kopo_channel_result_full_out',
#  'group3_middle_result',
#  'group3_gropby_avg_result',
#  'varification_original',
#  'team2_accuracy_result',
#  'student_score',
#  'kopo_channel_seasonality_final',
#  'kopo_channel_st_khk_final1',
#  'KOPO_ST_김효관_FINAL1',
#  'KOPO_ST_김효관_FINAL2',
#  'KOPO_ST_김효관_FINAL3',
#  'KOPO_ST_김효관_FINAL4',
#  'kopo_channel_seasonality_backup',
#  'notification_sequence',
#  'kjhgjhgjg',
#  'dept',
#  'boss',
#  'kopo_test',
#  'kopo_test2',
#  'aaa',
#  'aaaaaa',
#  'avav',
#  'KOPO_ST_이한민_FINAL2',
#  'KOPO_ST_이효재_FINAL3',
#  'KOPO_ST_이한민_FINAL1',
#  'KOPO_ST_이효재_FINAL1',
#  'KOPO_ST_이효재_FINAL2',
#  'key_constraints',
#  'txns',
#  'txn_components',
#  'completed_txn_components',
#  'next_txn_id',
#  'aa',
#  'kopo_1mil_data',
#  'kopo_predict_all_qa',
#  'parameter_v1',
#  'KOPO_REGION_MST_임태현',
#  'kopo_channel_result_new_notnull',
#  'kopo_channel_result_new_v1',
#  'tb1',
#  'tb2',
#  'item_list',
#  'cust_mgt',
#  'pro_fcst_result_final1',
#  'kopo_product_volume_pkajh',
#  'hm_test_address_book',
#  'hm_test_customer',
#  'hm_test_product',
#  'hm_test_order',
#  'hm_test_payment',
#  'new_volume_ajh',
#  'kopo_product_volume_pkajh2',
#  'kopo_quiz_222',
#  'kopo_product_volume_lkr1',
#  'leekyung',
#  'KOPO_PRODUCT_QUIZ_22_황정선',
#  'kopo12345',
#  'kopo_database_exam',
#  'middle_step3',
#  'test_py_0',
#  'group2_spark_result',
#  'group_param',
#  'kopo_database_exam_answer',
#  'kopo_product_volume4',
#  'kopo_product_volume5',
#  'kopo_stock_st_김효관',
#  'kopo_flatmapdoulbe_result',
#  'kopo_hm_account',
#  'kopo_resultnohivedouble_result',
#  'kopo_hm_customer',
#  'kopo_doublehivefull_result',
#  'kopo_hm_product',
#  'kopo_hm_order',
#  'KOPO_PROJECT_박승진_TEST5',
#  'testhyun',
#  'oracleresult',
#  'KOPO_PY_노영우_FINAL3',
#  'KOPO_PY_노영우',
#  'KOPO_PY_정답지_FINAL2',
#  '180711_team3_test',
#  'KOPO_STOCK_ST_김효관',
#  'kopo_stock_st_박승진',
#  'KOPO_STOCK_ST_박승진',
#  'team4_param_table',
#  'kopo_stock_st_a',
#  'kopo_stock_st_신성우',
#  'kopo_stock_st_정효재',
#  'kopo_stock_st_채성은',
#  'KOPO_STOCK_ST_채성은',
#  'kopo_stock_st_jkh',
#  'KOPO_PY_김도운_FINAL1',
#  'KOPO_PY_김지성_FINAL3',
#  'KOPO_STOCK_ST_김의진',
#  'kopo_stock_st_최경재',
#  'stockInfo_김강용',
#  'stock_info_김강용',
#  'KOPO_STOCK_ST_김지성',
#  'KOPO_STOCK_ST_정효재',
#  'KOPO_STOCK_ST_이한민',
#  'oracleresult_omj',
#  'KOPO_STOCK_ST_윤성호',
#  'stock_info_kgy',
#  'KOPO_STOCK_ST_최경재',
#  'kopo_stock_st_오미진',
#  'KOPO_STOCK_ST_이동근',
#  'KOPO_ST_박승진_FINAL3',
#  'KOPO_ST_정경화_FINAL5',
#  'KOPO_ST_이한민_FINAL3',
#  'KOPO_ST_이효재_FINAL4',
#  'KOPO_ST_이한민_FINAL6',
#  'KOPO_ST_이한민_FINAL4',
#  'kopo_st_dave_final2',
#  'KOPO_ST_최동훈_FINAL1',
#  'KOPO_ST_최동훈_FINAL2',
#  'KOPO_ST_정경화_FINAL1',
#  'KOPO_ST_박승진_FINAL5',
#  'KOPO_ST_하태양_FINAL3',
#  'KOPO_ST_정경화_FINAL2',
#  'KOPO_ST_박승진_FINAL4',
#  'KOPO_ST_이효재_FINAL6',
#  'KOPO_ST_김도운_FINAL1',
#  'KOPO_ST_정경화_FINAL3',
#  'KOPO_ST_정경화_FINAL6',
#  'KOPO_ST_이효재_FINAL5',
#  'KOPO_ST_박승진_FINAL1',
#  'KOPO_ST_이한민_FINAL5',
#  'KOPO_ST_정경화_FINAL4',
#  'KOPO_ST_노영우_FINAL1',
#  'KOPO_ST_박승진_FINAL6',
#  'KOPO_ST_김효관_FINAL5',
#  'KOPO_ST_박승진_FINAL2',
#  'kopo_st_dave_final3',
#  'KOPO_ST_신성우_FINAL1',
#  'KOPO_ST_윤성호_FINAL2',
#  'KOPO_ST_신성우_FINAL2',
#  'KOPO_ST_신성우_FINAL3',
#  'KOPO_ST_김의진_FINAL1',
#  'KOPO_ST_김의진_FINAL2',
#  'KOPO_ST_신성우_FINAL4',
#  'KOPO_ST_김의진_FINAL3',
#  'KOPO_ST_김의진_FINAL4',
#  'KOPO_ST_최동훈_FINAL3',
#  'KOPO_ST_채성은_FINAL2',
#  'kopo_event_info_foreign23',
#  'KOPO_ST_윤성호_FINAL3',
#  'KOPO_ST_채성은_FINAL3',
#  'KOPO_ST_노영우_FINAL2',
#  'KOPO_ST_김의진_FINAL5',
#  'KOPO_ST_이우석_FINAL3',
#  'KOPO_ST_채성은_FINAL4',
#  'KOPO_ST_김의진_FINAL6',
#  'kopo_st_dave_final4',
#  'KOPO_ST_이은실_FINAL2',
#  'KOPO_ST_정유석_FINAL1',
#  'KOPO_ST_최동훈_FINAL4',
#  'KOPO_ST_김강용_FINAL2',
#  'KOPO_ST_채성은_FINAL5',
#  'KOPO_ST_노영우_FINAL3',
#  'KOPO_ST_하태양_FINAL2',
#  'KOPO_ST_이우석_FINAL4',
#  'KOPO_ST_정유석_FINAL2',
#  'KOPO_ST_윤성호_FINAL4',
#  'KOPO_ST_노영우_FINAL4',
#  'KOPO_PROJECT_채성은_TEST',
#  'KOPO_PROJECT_박승진_TEST6',
#  'dw74',
#  'KOPO_PARAMETER_박승진9',
#  'KOPO_ST_조정연_FINAL2',
#  'KOPO_PROJECT_박승진_TEST7',
#  'KOPO_ST_김효관_FINAL6',
#  'KOPO_ST_채성은_FINAL1',
#  'KOPO_ST_노영우_FINAL5',
#  'KOPO_ST_최경재_FINAL2',
#  'KOPO_PARAMETER_박승진12',
#  'KOPO_ST_하태양_FINAL5',
#  'KOPO_ST_조정연_FINAL3',
#  'abcdfeee',
#  'KOPO_ST_하태양_FINAL1',
#  'result_py_11',
#  'KOPO_ST_이동근_FINAL1',
#  'KOPO_ST_채성은_FINAL6',
#  'KOPO_ST_오미진_FINAL5',
#  'seasonality_stddev',
#  'KOPO_ST_오미진_FINAL1',
#  'KOPO_ST_정효재_FINAL1',
#  'seasonality_refined',
#  'KOPO_ST_오미진_FINAL2',
#  'seasonality_ma',
#  'seasonality_cleansed',
#  'KOPO_ST_김강용_FINAL3',
#  'KOPO_ST_김강용_FINAL4',
#  'KOPO_ST_오미진_FINAL3',
#  'KOPO_ST_성한빈_FINAL2',
#  'KOPO_ST_오미진_FINAL4',
#  'KOPO_ST_조동역_FINAL2',
#  'KOPO_ST_오미진_FINAL6',
#  'KOPO_ST_조동역_FINAL3',
#  'KOPO_ST_정효재_FINAL2',
#  'KOPO_ST_이동근_FINAL2',
#  'kopo_st_dave_final5',
#  'KOPO_ST_김지성_FINAL1',
#  'KOPO_ST_김지성_FINAL2',
#  'KOPO_ST_최동훈_FINAL5',
#  'KOPO_ST_김지성_FINAL3',
#  'KOPO_ST_조정연_FINAL1',
#  'KOPO_ST_김지성_FINAL4',
#  'KOPO_ST_정유석_FINAL3',
#  'KOPO_ST_김지성_FINAL5',
#  'KOPO_ST_최경재_FINAL3',
#  'KOPO_ST_김지성_FINAL6',
#  'KOPO_ST_노영우_FINAL6',
#  'KOPO_ST_이동근_FINAL3',
#  'KOPO_ST_이우석_FINAL5',
#  'KOPO_ST_이동근_FINAL4',
#  'KOPO_ST_정효재_FINAL3',
#  'KOPO_ST_이은실_FINAL',
#  'KOPO_ST_김강용_FINAL6',
#  'KOPO_ST_김효관_FINAL',
#  'KOPO_ST_정효재_FINAL4',
#  'KOPO_ST_성한빈_FINAL4',
#  'KOPO_ST_윤성호_FINAL1',
#  'KOPO_ST_정유석_FINAL4',
#  'KOPO_ST_최경재_FINAL4',
#  'KOPO_ST_정효재_FINAL5',
#  'KOPO_ST_성한빈_FINAL5',
#  'KOPO_ST_윤성호_FINAL5',
#  'KOPO_ST_최경재_FINAL6',
#  'KOPO_ST_하태양_FINAL6',
#  'KOPO_ST_정효재_FINAL6',
#  'KOPO_ST_조정연_FINAL4',
#  'KOPO_ST_조정연_FINAL5',
#  'KOPO_ST_정유석_FINAL5',
#  'KOPO_ST_윤성호_FINAL6',
#  'KOPO_ST_최경재_FINAL5',
#  'kopo_st_dave_final6',
#  'KOPO_ST_이우석_FINAL1',
#  'KOPO_ST_최동훈_FINAL6',
#  'KOPO_ST_김강용_FINAL1',
#  'KOPO_ST_이동근_FINAL5',
#  'KOPO_ST_신성우_FINAL5',
#  'KOPO_ST_신성우_FINAL6',
#  'KOPO_ST_김강용_FINAL5',
#  'KOPO_ST_성한빈_FINAL6',
#  'KOPO_ST_정유석_FINAL6',
#  'KOPO_ST_이동근_FINAL6',
#  'KOPO_FINAL_김강용',
#  'x_db_version_h',
#  'dt_result_final4',
#  'dt_result_final2',
#  'test0987',
#  'oracleresult_ysh',
#  'oracleresult_ejkim',
#  'oracleresult_kdw',
#  'myfcst',
#  'step5_bk',
#  'myavg',
#  'step4_bk',
#  'step6_bk',
#  'final_suhbohkuk',
#  'finalmyfcst',
#  'final_step2',
#  'final_step3',
#  'hk_parameter',
#  'kopo_mytable',
#  'final_step4',
#  'targetdata',
#  'leeluna',
#  'param',
#  'final4',
#  'lesresult',
#  'psj_test_test',
#  'step1_sy',
#  'x_portal_user',
#  'x_portal_user_role',
#  'xa_access_audit',
#  'x_asset',
#  'x_auth_sess',
#  'x_cred_store',
#  'x_db_base',
#  'x_group',
#  'x_group_groups',
#  'x_user',
#  'x_group_users',
#  'dt_result_final_pivot',
#  'pro_fcst_result_1week',
#  'pro_fcst_result_2week',
#  'pro_fcst_result_3week',
#  'pro_fcst_result_4week',
#  'pro_fcst_result_5week',
#  'pro_fcst_result_6week',
#  'subquery_a',
#  'subquery_b',
#  'lsw_answer',
#  'final_step33',
#  'region_master',
#  'promotion_master',
#  'final_2019st_taeyeopjo',
#  'final_2019st_haerikim',
#  'final_2019st_limtaehyun',
#  'final_2019st_kojiin',
#  'final_2019st_kimsunglim',
#  'final_2019st_hyokwan',
#  'final_2019st_kwonseulki',
#  'final_2019st_wongeun',
#  'final_2019st_yeageun',
#  'KOPO_ST_성한빈_FINAL1',
#  'KOPO_ST_김강용_FINALA',
#  'KOPO_ST_김강용_FINALB',
#  'KOPO_ST_김강용_FINALC',
#  'KOPO_ST_성한빈_FINAL3',
#  'KOPO_ST_김강용_FINALD',
#  'KOPO_ST_김강용_FINALE',
#  'suntest1',
#  'rhror',
#  'wnans',
#  'wnans1',
#  'test_hk_spark',
#  'KOPO_SPARK_ST_노영우_FINALTEST',
#  'KOPO_SPARK_ST_이한민',
#  'KOPO_SPARK_ST_박승진',
#  'cmsproduct',
#  'cms2',
#  'kopo_channel_result_full',
#  'kopo_channel_target_full',
#  'KOPO_SPARK_ST_신성우',
#  'KOPO_SPARK_ST_김지성',
#  'KOPO_SPARK_ST_신성우_TEST',
#  'KOPO_SPARK_ST_채성은',
#  'KOPO_SPARK_ST_윤성호',
#  'KOPO_SPARK_ST_김효관',
#  'KOPO_SPARK_ST_노영우',
#  'KOPO_SPARK_ST_최경재',
#  'KOPO_SPARK_ST_김강용',
#  'KOPO_SPARK_ST_정경화',
#  'KOPO_SPARK_ST_하태양1',
#  'KOPO_SPARK_ST_이우석',
#  'KOPO_SPARK_ST_하태양',
#  'KOPO_PY_오미진_FINAL1',
#  'group2_result',
#  'test_py_111',
#  'ppt',
#  'KOPO_PY_이한민_FINAL1',
#  'KOPO_PY_최경재_FINAL1',
#  'KOPO_PY_조정연_FINAL1',
#  'KOPO_PY_이은실_FINAL1',
#  'kopo_py_dave_final1',
#  'KOPO_PY_성한빈_FINAL1',
#  'KOPO_PY_김의진_FINAL1',
#  'KOPO_PY_하태양_FINAL2',
#  'thirdtable',
#  'KOPO_PY_김강용_FINAL1',
#  'param_group3',
#  'kopo_psj_product',
#  'kopo_psj_user',
#  'x_enum_def',
#  'x_enum_element_def',
#  'x_service_config_map',
#  'x_policy_resource',
#  'x_policy_resource_map',
#  'x_policy_item',
#  'x_policy_item_access',
#  'x_policy_item_condition',
#  'x_policy_item_user_perm',
#  'x_policy_item_group_perm',
#  'x_data_hist',
#  'x_modules_master',
#  'x_user_module_perm',
#  'x_group_module_perm',
#  'x_tag_def',
#  'x_tag',
#  'x_service_resource',
#  'x_service_resource_element',
#  'team4_seasonality_spark',
#  'x_tag_attr_def',
#  'x_tag_attr',
#  'x_tag_resource_map',
#  'x_service_resource_element_val',
#  'x_datamask_type_def',
#  'x_policy_item_datamask',
#  'x_policy_item_rowfilter',
#  'x_service_version_info',
#  'kopo_py_dave_final2',
#  'KOPO_PY_신성우_FINAL2',
#  'KOPO_PY_노영우_FINAL2',
#  'KOPO_PY_성한빈_FINAL2',
#  'KOPO_PY_최경재_FINAL2',
#  'elecResult',
#  'elecresult',
#  'oracleresult2',
#  'test_py_jjjj',
#  'seasonality_team1',
#  'param_5joe_ver3',
#  'TEST_PY_0_jjjj',
#  'param_5joe',
#  'team3_middleresult',
#  'team2_result',
#  'project_kgy',
#  'team3_middleresult2',
#  'ora_result',
#  'team3_decisiontree_error',
#  't3_seasonality_index',
#  'kopo_fullcolumn_result',
#  'kopo_si_update_result',
#  'kopo_product_volume_seobseob',
#  'kopo_product_volume_kh',
#  'kopo_product_volumeh',
#  'txData.csv',
#  'kopo_predict_middleresult3_jar',
#  'kopo_channel_seasonality_jar',
#  'kopo_channel_seasonality_ap2id',
#  'kopo_batch_season_result_11_19',
#  'sequence_table',
#  'nucleus_tables',
#  'kopo_product_volume_hs2',
#  'KOPO_PY_이한민_FINAL2',
#  'KOPO_PY_정효재_FINAL2',
#  'KOPO_PY_정효재_FINAL1',
#  'team3_seasonality_py',
#  'KOPO_PY_정유석_FINAL1',
#  'team3_seasonality_final_py',
#  'team3_seasonality_1a',
#  'team3_seasonality_final_1a',
#  'team3_seasonality_2a',
#  'team3_seasonality_final_2a',
#  'team3_seasonality_2b',
#  'team4_seasonality_sql',
#  '사용자정보',
#  '주소록',
#  '상품정보',
#  '주문정보',
#  'kopo_customerdata_songjinwoo',
#  'kopo_customerdata_sonjinwoo',
#  'kopo_customerdata_jinwoo',
#  'KOPO_PY_김지성_FINAL1',
#  'py_finalData',
#  'kopo_lucky_smoothing_result',
#  'KOPO_PY_김강용_FINAL222',
#  'KOPO_PY_김강용_FINAL2',
#  'Team2',
#  'kopo_adj_qty_result',
#  'kopo_py_ldg_final2',
#  'KOPO_PY_성한빈_FINAL3_dateconcat',
#  'final_2019st_sinwoo',
#  'users_git',
#  'wise',
#  'kokopopo',
#  'KOPO_PY_FINAL_성한빈',
#  'ex_card',
#  'ex_card_ajh',
#  'ex_card_new',
#  'ex_card007',
#  'ex_card1234',
#  'ex_card1',
#  'hightec',
#  'KOPO22_ST_임은철_FINAL',
#  'KOPO22_ST_장윤지_FIANL1',
#  'KOPO22_ST_임은철_FINAL2',
#  'KOPO22_ST_장윤지_FINAL2',
#  'KOPO_PY_채성은_FINAL2',
#  'KOPO22_ST_문상우_FINAL1',
#  'KOPO22_ST_이진환_FINAL1',
#  'KOPO22_ST_김다슬_FINAL1',
#  'KOPO22_ST_남성환_FINAL1',
#  'KOPO22_ST_이진환_FINAL2',
#  'kopo_ldg_111',
#  'KOPO_PY_정경화_FINAL2',
#  'KOPO_PY_조동역_FINAL2',
#  'KOPO_PY_윤성호_FINAL3',
#  'kopo_py_ldg_final5',
#  'KOPO_PY_이효재_FINAL3',
#  'KOPO_PY_조동역_FINAL3',
#  't3_seasonality2',
#  'group2_ma_result',
#  'group2_stdev_result',
#  'kopo_parameter_omz',
#  'seasonality_smoothed',
#  'seasonality_index',
#  'seasonality_index_final',
#  'KOPO_PY_최경재_FINAL3',
#  'KOPO_PY_신성우_FINAL3',
#  'kopo_channel_seasonality_result_omz',
#  'kopo_ma_stddev_result',
#  'KOPO_SPARK_ST_김의진',
#  'flat_st_',
#  'flat_st',
#  'KOPO_PY_김강용_FINAL3',
#  't3_seasonality2_index',
#  'KOPO_PY_김지성_FINAL4',
#  'KOPO_PY_채성은_FINAL3',
#  'x_plugin_info',
#  'x_policy_label',
#  'x_policy_label_map',
#  'KOPO_PY_정경화_FINAL3',
#  'KOPO_SPARK_ST_정효재_REVISED',
#  'x_ugsync_audit_info',
#  'hive_locks',
#  'kopo_psj_psj',
#  'kopo_grouptable_result',
#  'next_lock_id',
#  'compaction_queue',
#  'kopo_table_result',
#  'kopo_middletable1_result',
#  'next_compaction_queue_id',
#  'completed_compactions',
#  'ldg_kopo_channel_result_a01',
#  'aux_table',
#  'write_set',
#  'kopo_gfk_result_leehyojae',
#  'users2',
#  'ckjboard',
#  'kopo_channel_result_a01_sun',
#  'kopo_channel_result_a01_sun1',
#  'kopo_gfk_result_leehyoja1e',
#  'group2_1',
#  'group2_2',
#  'python_seasonality',
#  'test11',
#  'test_kgy',
#  'result_py',
#  'kopo_channel_test_result',
#  'kopo_channel_test_result2',
#  'result_py1',
#  'group2_3',
#  'kopo_hk_py',
#  'KOPO_PROJECT_박승진_TEST1',
#  'group2_db',
#  'KOPO_PROJECT_박승진_TEST4',
#  'group2_5',
#  'group2_4',
#  'kopo_channel_hk5',
#  'KOPO_PROJECT_채성은',
#  'result_py_0',
#  'KOPO_PROJECT_박승진_TEST',
#  'KOPO_PROJECT_박승진_TEST2',
#  'KOPO_PROJECT_박승진_TEST3',
#  'kopo_resultnohive_result',
#  'kopo_nonhivefull_result',
#  'kopo_seasonality_ckj',
#  'result_py11',
#  'fcstresult',
#  'param_5joe_ver2',
#  'finalseasonalitydata2',
#  'finalseasonalitydata3',
#  'seasonalitydata5',
#  'seasonalitydata6',
#  'kopo_prodcut_volume',
#  'kopo_customerdata2',
#  'kopo_promotion_2',
#  'kopo_promotion3',
#  'kopo_promotion2',
#  'kopo_promotion4',
#  'kopo_promotionee',
#  ...]

# %%
# csv 파일 불러오기
sawonData = pd.read_csv("./사원.csv", encoding="ms949")
sawonData = pd.DataFrame()
sawonData.values

# %%
# 1. 급여가 800만원 이상인 사원의 사원명, 직급코드를 출력하시오
sawonData.loc
# Out:
#      사원번호   사원명  직급코드 근무지코드 부서코드  상급자사원번호          급여              입사일
# 0   102.0   김존형  60.0    A1    S      NaN   8346000.0  2004-05-02 0:00
# 1   103.0   유광전  50.0    A1    E      NaN   8900000.0  2006-12-06 0:00
# 2   104.0   김은목  50.0    A1    G    101.0   5430000.0  2012-09-14 0:00
# 3   105.0   임기옹  30.0    A1    E    103.0  10000000.0  2011-04-23 0:00
# 4   106.0   윤영삭  20.0    A1    G    101.0   4400000.0  2016-01-09 0:00
# 5   107.0   윤문옹  50.0    A1    S    102.0   7090000.0  2018-08-19 0:00
# 6   108.0   엄자호  50.0    A1    E    103.0   6400000.0  2018-02-24 0:00
# 7   109.0   서겸민  20.0    B1    C    101.0   3100000.0  2020-06-10 0:00
# 8   110.0   김민삭  10.0    B1    C    101.0   2200000.0  2020-08-01 0:00
# 9   111.0   한요리  10.0    B1    C    101.0   2300000.0  2020-08-01 0:00
# 10  112.0    공햔  10.0    B1    C    101.0   2200000.0  2020-08-01 0:00
# 11  113.0   김재양  10.0    B1    C    101.0   2400000.0  2020-08-01 0:00
# 12  114.0    한술  10.0    B1    T    101.0   2500000.0  2020-08-01 0:00
# 13  115.0   정샤인  10.0    A1    G    103.0   2350000.0  2020-08-20 0:00
# 14  116.0   문산윤  10.0    A1    G    103.0   2350000.0  2020-08-20 0:00
# 15  101.0   허잔석  60.0    A1    G      NaN   8530000.0  2001-03-07 0:00
# 16  117.0  김123  50.0    A1    E    103.0   9012530.0  2020-09-07 0:00
# 17  118.0    안청  50.0    A1    E    103.0   9553200.0  2020-09-07 0:00
# 18    NaN   NaN   NaN   NaN  NaN      NaN         NaN              NaN

# %%
tableName = "JIKGB_TEST"

#### 문자컬럼에 대해서 varchar (100) 적용 _ 사용시 속도 SpeedUp 50배 
objectColumns = list(sawonData.columns[sawonData.dtypes == 'object'])
typeDict={}
maxLen = 100

for i in range(0, len(objectColumns)):
    # sawonData[i].str.len().max() 최대치 사용할 경우
    typeDict[ objectColumns[i] ] = types.VARCHAR(100)
#### 문자컬럼에 대해서 varchar (100) 적용 _ 사용시 속도 SpeedUp 50배 

sawonData.to_sql(name=tableName, if_exists="replace", con=engine,dtype=typeDict, index=False)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14112\3580608106.py in <module>
#      11 #### 문자컬럼에 대해서 varchar (100) 적용 _ 사용시 속도 SpeedUp 50배
#      12
# ---> 13 sawonData.to_sql(name=tableName, if_exists="replace", con=engine,dtype=typeDict, index=False)
#
# c:\Users\SMART07\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# c:\Users\SMART07\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# c:\Users\SMART07\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1730         sql_engine = get_engine(engine)
#    1731
# -> 1732         table = self.prep_table(
#    1733             frame=frame,
#    1734             name=name,
#
# c:\Users\SMART07\anaconda3\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1629             dtype=dtype,
#    1630         )
# -> 1631         table.create()
#    1632         return table
#    1633
#
# c:\Users\SMART07\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     834                 raise ValueError(f"Table '{self.name}' already exists.")
#     835             elif self.if_exists == "replace":
# --> 836                 self.pd_sql.drop_table(self.name, self.schema)
#     837                 self._execute_create()
#     838             elif self.if_exists == "append":
#
# c:\Users\SMART07\anaconda3\lib\site-packages\pandas\io\sql.py in drop_table(self, table_name, schema)
#    1788         schema = schema or self.meta.schema
#    1789         if self.has_table(table_name, schema):
# -> 1790             self.meta.reflect(bind=self.connectable, only=[table_name], schema=schema)
#    1791             self.get_table(table_name, schema).drop(bind=self.connectable)
#    1792             self.meta.clear()
#
# c:\Users\SMART07\anaconda3\lib\site-packages\sqlalchemy\sql\schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4873                 if missing:
#    4874                     s = schema and (" schema '%s'" % schema) or ""
# -> 4875                     raise exc.InvalidRequestError(
#    4876                         "Could not reflect: requested table(s) not available "
#    4877                         "in %r%s: (%s)" % (bind.engine, s, ", ".join(missing))
#
# InvalidRequestError: Could not reflect: requested table(s) not available in Engine(oracle+cx_oracle://kopo:***@192.168.110.112:1521/orcl): (JIKGB_TEST)

# %%
BUSEO_TEST
SAWON_TEST
KNMUJI_TEST
JIKGB_TEST
