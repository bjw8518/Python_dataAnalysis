# %%
targetUrl ="https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002633405&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B4%80%EB%A0%A8%20%EC%A7%80%EC%88%98_20160101"

# %%
import pandas as pd

# %%
inData = pd.read_csv(targetUrl, encoding="ms949")

# %%
pd.read_csv(targetUrl, encoding="ms949")
# Out:
#              연도  전국소득대비 주택가격 비율  서울소득대비 주택가격 비율  부산소득대비 주택가격 비율  \
# 0    2004-01-01            4.21            4.89            3.95
# 1    2004-01-01            4.39            5.59            3.91
# 2    2004-01-01            4.19            5.14            4.90
# 3    2004-01-01            4.09            4.38            4.20
# 4    2004-01-01            4.29            5.88            4.43
# ..          ...             ...             ...             ...
# 138  2015-01-01            5.43            6.80            5.47
# 139  2015-01-01            5.57            6.87            5.49
# 140  2015-01-01            5.61            7.12            5.54
# 141  2015-01-01            5.68            7.18            5.78
# 142  2016-01-01            4.31            7.30            5.73
#
#      대구소득대비 주택가격 비율  인천소득대비 주택가격 비율  광주소득대비 주택가격 비율  대전소득대비 주택가격 비율  \
# 0              3.73            4.65            2.81            4.68
# ...

# %%
inData
# Out:
#              연도  전국소득대비 주택가격 비율  서울소득대비 주택가격 비율  부산소득대비 주택가격 비율  \
# 0    2004-01-01            4.21            4.89            3.95
# 1    2004-01-01            4.39            5.59            3.91
# 2    2004-01-01            4.19            5.14            4.90
# 3    2004-01-01            4.09            4.38            4.20
# 4    2004-01-01            4.29            5.88            4.43
# ..          ...             ...             ...             ...
# 138  2015-01-01            5.43            6.80            5.47
# 139  2015-01-01            5.57            6.87            5.49
# 140  2015-01-01            5.61            7.12            5.54
# 141  2015-01-01            5.68            7.18            5.78
# 142  2016-01-01            4.31            7.30            5.73
#
#      대구소득대비 주택가격 비율  인천소득대비 주택가격 비율  광주소득대비 주택가격 비율  대전소득대비 주택가격 비율  \
# 0              3.73            4.65            2.81            4.68
# ...

# %%
carDataUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/cars.csv"

# %%
carsData = pd.read_csv(carDataUrl, encoding="ms949")

# %%
carsData
# Out:
#      age  gender  miles   debt  income  sales
# 0     28       0     23      0    4099    620
# 1     26       0     27      0    2677   1792
# 2     30       1     58  41576    6215  27754
# 3     26       1     25  43172    7626  28256
# 4     20       1     17   6979    8071   4438
# ..   ...     ...    ...    ...     ...    ...
# 958   22       0     11   8778    9829   1593
# 959   19       1     23   4850    3470   4742
# 960   28       1     28   9312    2720  12771
# 961   50       0     29  51343    8713  28511
# 962   47       1     15   3735    6406   6104
#
# [963 rows x 6 columns]

# %%
inData.tail(2)
# Out:
#              연도  전국소득대비 주택가격 비율  서울소득대비 주택가격 비율  부산소득대비 주택가격 비율  \
# 141  2015-01-01            5.68            7.18            5.78
# 142  2016-01-01            4.31            7.30            5.73
#
#      대구소득대비 주택가격 비율  인천소득대비 주택가격 비율  광주소득대비 주택가격 비율  대전소득대비 주택가격 비율  \
# 141            6.48            5.76            5.46            5.17
# 142            6.88            5.74            4.92            4.79
#
#      울산소득대비 주택가격 비율  세종소득대비 주택가격 비율  ...  세종평균 대출금액  평균 연소득  \
# 141            5.11            5.22  ...               2.17
# 142            5.38            5.76  ...               2.39
#
#      경기평균 대출금액  평균 연소득  강원평균 대출금액  평균 연소득  충북평균 대출금액  평균 연소득  \
# 141               2.56               1.95               2.11
# 142               2.38               1.74               1.83
#
#      충남평균 대출금액  평균 연소득  전북평균 대출금액  평균 연소득  전남평균 대출금액  평균 연소득  \
# 141               2.02               1.88               1.67
# 142               1.81               1.63               1.75
#
# ...

# %%
import pandas as pd

# %%
op="https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002579913&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EB%B6%80%EB%8F%99%EC%82%B0%EC%9B%90_%EC%98%A4%ED%94%BC%EC%8A%A4%ED%85%94%20%EA%B0%80%EA%B2%A9%EB%8F%99%ED%96%A5%EC%A1%B0%EC%82%AC_%EC%A0%84%EC%84%B8%EA%B0%80%EA%B2%A9(%EC%A7%80%EC%97%AD%EB%B3%84)_20220630"

# %%
opLink = pd.read_csv(op, encoding="ms949")

# %%
opLink.head(3)
# Out:
#     지역  2020-07(평균전세가격)  2020-07(평균단위당전세가격)  2020-07(중위전세가격)  \
# 0   전국           163525                4370           156386
# 1  수도권           175996                4797           167524
# 2   지방           111980                2603           110353
#
#    2020-07(중위단위당전세가격)  2020-08(평균전세가격)  2020-08(평균단위당전세가격)  2020-08(중위전세가격)  \
# 0                4266           163768                4376           156762
# 1                4682           176294                4805           167927
# 2                2545           111998                2603           110617
#
#    2020-08(중위단위당전세가격)  2020-09(평균전세가격)  ...  2022-04(중위전세가격)  \
# 0                4273           164087  ...           163344
# 1                4690           176681  ...           175075
# 2                2547           112035  ...           114860
#
#    2022-04(중위단위당전세가격)  2022-05(평균전세가격)  2022-05(평균단위당전세가격)  2022-05(중위전세가격)  \
# 0                4424           172911                4573           163537
# ...

# %%
postNum ="https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002336443&fileDetailSn=1&dataNm=%ED%86%B5%EA%B3%84%EC%B2%AD_%EB%82%98%EB%9D%BC%ED%86%B5%EA%B3%84_%EC%9A%B0%ED%8E%B8%EB%B2%88%ED%98%B8_20211110"

# %%
postNumCountry = pd.read_csv(postNum, encoding="ms949")

# %%
postNumCountry
# Out:
#          우편번호  우편번호순서    도이름 시군구이름 읍면동이름         리건물이름              동호  \
# 0      137926      11  서울특별시   서초구  서초1동           NaN  1641-1~1641-13
# 1      137927      11  서울특별시   서초구  서초3동           NaN            1451
# 2      137929      12  서울특별시   서초구  서초4동  서초교대e편한세상아파트      (101~106동)
# 3      137930       2  서울특별시   서초구  반포1동       반포자이아파트      (101~144동)
# 4      137931       2  서울특별시   서초구  반포1동       삼호가든아파트      (501~503동)
# ...       ...     ...    ...   ...   ...           ...             ...
# 52538  799821      31   경상북도   울릉군    북면            나리             NaN
# 52539  799822      21   경상북도   울릉군    북면          천부4리             NaN
# 52540  799822      11   경상북도   울릉군    북면          천부3리             NaN
# 52541  799822       1   경상북도   울릉군    북면          나리2리             NaN
# 52542  799823       1   경상북도   울릉군    북면           현포리             NaN
#
#                                          전체주소
# 0               서울특별시 서초구 서초1동 1641-1~1641-13
# ...

# %%
jsonUrl="https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=ZWU2NmI4ZmRmNWEyNWJjMTExNmQzNTVhZDliYmE4YTQ=&itmId=T20+T21+T22+&objL1=ALL&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&newEstPrdCnt=3&orgId=101&tblId=DT_1B040A3"

# %%
manData = pd.read_json(jsonUrl)
manData.head(10)
# Out:
#               TBL_NM  PRD_DE      TBL_ID ITM_NM        ITM_NM_ENG ITM_ID  \
# 0  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3   총인구수   Koreans (Total)    T20
# 1  행정구역(시군구)별 성별 인구수  202301  DT_1B040A3   총인구수   Koreans (Total)    T20
# 2  행정구역(시군구)별 성별 인구수  202302  DT_1B040A3   총인구수   Koreans (Total)    T20
# 3  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 4  행정구역(시군구)별 성별 인구수  202301  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 5  행정구역(시군구)별 성별 인구수  202302  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 6  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 7  행정구역(시군구)별 성별 인구수  202301  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 8  행정구역(시군구)별 성별 인구수  202302  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 9  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3   총인구수   Koreans (Total)    T20
#
#   UNIT_NM  ORG_ID UNIT_NM_ENG   C1_OBJ_NM               C1_OBJ_NM_ENG  \
# 0       명     101      Person  행정구역(시군구)별  By Administrative District
# ...

# %%
daeChoolJson = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=ZWU2NmI4ZmRmNWEyNWJjMTExNmQzNTVhZDliYmE4YTQ=&itmId=T001+&objL1=ALL&objL2=ALL&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=101&tblId=DT_1MA0027"

# %%
dC = pd.read_json(daeChoolJson)
dC.head(10)
# Out:
#             TBL_NM  PRD_DE      TBL_ID ITM_NM  ITM_NM_ENG ITM_ID UNIT_NM  \
# 0  금융권 대출잔액 수준별 인구    2019  DT_1MA0027    인구수  Population   T001      천명
# 1  금융권 대출잔액 수준별 인구    2020  DT_1MA0027    인구수  Population   T001      천명
# 2  금융권 대출잔액 수준별 인구    2021  DT_1MA0027    인구수  Population   T001      천명
# 3  금융권 대출잔액 수준별 인구    2019  DT_1MA0027    인구수  Population   T001      천명
# 4  금융권 대출잔액 수준별 인구    2020  DT_1MA0027    인구수  Population   T001      천명
# 5  금융권 대출잔액 수준별 인구    2021  DT_1MA0027    인구수  Population   T001      천명
# 6  금융권 대출잔액 수준별 인구    2019  DT_1MA0027    인구수  Population   T001      천명
# 7  금융권 대출잔액 수준별 인구    2020  DT_1MA0027    인구수  Population   T001      천명
# 8  금융권 대출잔액 수준별 인구    2021  DT_1MA0027    인구수  Population   T001      천명
# 9  금융권 대출잔액 수준별 인구    2019  DT_1MA0027    인구수  Population   T001      천명
#
#    ORG_ID  UNIT_NM_ENG C1_OBJ_NM     C2_OBJ_NM  C2_OBJ_NM_ENG       DT PRD_SE  \
# 0     101  1000Persons       특성별  금융권 대출잔액 수준별  By dept level  12759.7      A
# ...
