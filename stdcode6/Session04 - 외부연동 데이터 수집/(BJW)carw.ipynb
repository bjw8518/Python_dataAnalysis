# %%
import requests, bs4
import pandas as pd

# %%
#웹페이지 html 소스 가져오기
resp = requests.get("https://www.enuri.com/list.jsp?cate=0404&from=search&keyword=%EB%85%B8%ED%8A%B8%EB%B6%81&skeyword=%EB%85%B8%ED%8A%B8%EB%B6%81")
resp.encoding='utf-8'
webPageSrc = resp.text

htmlObj = bs4.BeautifulSoup(webPageSrc, 'html.parser')
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="ko" http-equiv="content-language"/>
# <meta content="width=1280" name="viewport"/>
# <meta content="index,follow" name="robots"/>
# <meta content="i3iy8EZEHsBx3s1X4hdKDgRnSpiySOlDnc_q2in6yP8" name="google-site-verification"/>
# <title>노트북 - 에누리 가격비교</title> <!-- 해당카테고리 – 에누리 가격비교 -->
# <link href="https://img.enuri.info/2014/layout/favicon_enuri.ico" rel="shortcut icon"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//enuri.com" rel="dns-prefetch">
# <link href="//storage.enuri.info" rel="dns-prefetch"/>
# <link href="//img.enuri.com" rel="dns-prefetch"/>
# <link href="//photo3.enuri.info" rel="dns-prefetch"/>
# <link href="//ad-cdn.enuri.info" rel="dns-prefetch"/>
# <link href="//image.enuri.info" rel="dns-prefetch"/>
# ...

# %%
try:
    resp = requests.get("https://www.enuri.com/list.jsp?cate=0404&from=search&keyword=%EB%85%B8%ED%8A%B8%EB%B6%81&skeyword=%EB%85%B8%ED%8A%B8%EB%B6%81")
except Exception as e:
    print(e)

# %%
resp
# Out:
# <Response [200]>

# %%
div = htmlObj.find(name = "div", attrs = {"class" : "goods-bundle"} )

# %%
div
