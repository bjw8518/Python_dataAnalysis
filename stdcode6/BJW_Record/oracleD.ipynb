# %%
import pandas as pd
from sqlalchemy import create_engine, types
import os

# Oracle 데이터베이스 연결 설정
hostname = '192.168.110.7'
port = '1521'
database = 'XE'
username = 'BJW8518'
password = 'kopo'

engine = create_engine('oracle://{username}:{password}@{hostname}:{port}/{database}', echo=True)

paramData=pd.read_sql_query(sql="select * from BJW", con = engine)

paramData
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# c:\Users\SMART07\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# c:\Users\SMART07\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# c:\Users\SMART07\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# c:\Users\SMART07\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...
